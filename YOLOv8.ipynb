# %% [markdown]
# # **rock-paper-scissors**

# %%
# !pip install roboflow

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
import cv2

model = YOLO('yolov8n.pt')

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="api_key")
project = rf.workspace("roboflow-58fyf").project("rock-paper-scissors-sxsw")
version = project.version(14)
dataset = version.download("yolov8")

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/rock-paper-scissors-14/data.yaml epochs=10 imgsz=640 plots=True

# %%
from IPython.display import display, Image
Image(filename=f'/content/runs/detect/train/confusion_matrix.png',width=600)

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt data=/content/rock-paper-scissors-14/data.yaml

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt conf=0.5  source=/content/rock-paper-scissors-14/test/images

# %%
import glob
from IPython.display import display, Image
for image_path in glob.glob(f'/content/runs/detect/predict//*.jpg'):
  display(Image(filename=image_path,height=600))
  print('\n')

# %% [markdown]
# # **Manufacturing Item**

# %%
# !pip install roboflow
# !pip install ultralytics

# %%
from ultralytics import YOLO
import cv2

model = YOLO('yolov8n.pt')

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="6sXzmgdclk2X7wFjCOgq")
project = rf.workspace("computer-vision-ihl9n").project("cv-project-fins0")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.92, to fix: `pip install ultralytics==8.0.196`

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/cv-project-2/data.yaml epochs=10 imgsz=640 plots=True
# Out:
# Ultralytics YOLOv8.2.92 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from IPython.display import display, Image
Image(filename=f'/content/runs/detect/train2/confusion_matrix.png',width=600)

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train2/weights/best.pt data=/content/cv-project-2/data.yaml
# Out:
# Ultralytics YOLOv8.2.92 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,007,988 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/cv-project-2/valid/labels.cache... 632 images, 0 backgrounds, 0 corrupt: 100% 632/632 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 24, len(boxes) = 1882. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 40/40 [00:11<00:00,  3.55it/s]
#                    all        632       1882      0.551       0.71      0.666       0.47
#                  boots        163        338      0.834      0.899      0.924      0.667
#                 gloves        170        318      0.545      0.535      0.556       0.22
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train2/weights/best.pt conf=0.5  source=/content/cv-project-2/test/images
# Out:
# Ultralytics YOLOv8.2.92 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,007,988 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/502 /content/cv-project-2/test/images/00011_jpg.rf.4911f914e613e2add4e044a6af578764.jpg: 640x640 2 persons, 2 vests, 8.5ms
# image 2/502 /content/cv-project-2/test/images/00121_jpg.rf.4fafc3f20e6196bc8dad85818729a9cd.jpg: 640x640 1 person, 1 vest, 7.5ms
# image 3/502 /content/cv-project-2/test/images/00121_jpg.rf.f883f7011081210a3322561b164d91a6.jpg: 640x640 1 person, 1 vest, 7.4ms
# image 4/502 /content/cv-project-2/test/images/00122_jpg.rf.7d7865ff8a9dbea6ce4c3a97fbfe2718.jpg: 640x640 1 person, 1 vest, 7.4ms
# image 5/502 /content/cv-project-2/test/images/00225_jpg.rf.3a592f501b281cf1a61fb17f2277a51d.jpg: 640x640 (no detections), 7.4ms
# image 6/502 /content/cv-project-2/test/images/0_12027918_jpg.rf.f1d1d16abfdb4ea609e57c89f9c197be.jpg: 640x640 1 helmet_blue, 1 helmet_white, 7.4ms
# ...

# %%
import glob
from IPython.display import display, Image
for image_path in glob.glob(f'/content/runs/detect/predict//*.jpg'):
  display(Image(filename=image_path,height=600))
  print('\n')
# Out:
# Output hidden; open in https://colab.research.google.com to view.
